# %% [markdown]
# <a href="https://colab.research.google.com/github/KarineAyrs/science_work/blob/main/training/improved_classification_with_wandb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install timm
# Out:
# Collecting timm
#   Downloading timm-0.4.12-py3-none-any.whl (376 kB)
#      |████████████████████████████████| 376 kB 5.3 MB/s
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from timm) (0.10.0+cu111)
# Requirement already satisfied: torch>=1.4 in /usr/local/lib/python3.7/dist-packages (from timm) (1.9.0+cu111)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.4->timm) (3.7.4.3)
# Requirement already satisfied: pillow>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->timm) (7.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision->timm) (1.19.5)
# Installing collected packages: timm
# Successfully installed timm-0.4.12

# %%
# !pip install wandb

# %%
import timm
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader
import torchvision.datasets as datasets
import torchvision.transforms as transforms
import wandb

# %%
wandb.login()
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
class TimmModel(nn.Module):

    def __init__(self, model_name='efficientnet_b0', pretrained=True):

        super(TimmModel, self).__init__()
        self._model_name = model_name
        self._pretrained = pretrained
        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        self.model = timm.create_model(model_name=model_name, pretrained=pretrained)
        self.model.train()
        self.config = False
        if torch.cuda.is_available():
            self.model.cuda()

    def model_config(self, learning_rate=0.001, batch_size=2, num_epochs=5, criterion=None, optimizer=None):
        self.lr = learning_rate
        self.batch_size = batch_size
        self.num_epochs = 5
        self.criterion = nn.CrossEntropyLoss() if criterion is None else criterion
        self.optimizer = optim.Adam(self.model.parameters(), lr=learning_rate) if optimizer is None else optimizer
        self.config = True

    def train_model(self, train_loader):
        if not self.config:
          self.model_config()

        wandb.init(project='mnist-classification')
        wandb.config={'learning_rate': self.lr, 'epochs': self.num_epochs, 'batch_size': self.batch_size}
        wandb.watch(model, criterion=self.criterion, log='all',log_freq=10)

        total_batches = len(train_loader)*self.num_epochs        
        example_ct = 0 # number of examples seen
        batch_ct = 0

        for epoch in range(1, self.num_epochs + 1, 1):

            print(f'epoch:{epoch}')

            for batch, (data, targets) in enumerate(train_loader):

                data = data.to(device=self.device)
                targets = targets.to(device=self.device)

                example_ct+=len(data)
                batch_ct+=1

                

                if not self._model_name.startswith('vit'):
                    data = data.repeat(1, 3, 1, 1)
                else:
                    data = data.repeat(1, 3, 8, 8)

                scores = self.model(data)
                loss = self.criterion(scores, targets)

                if((batch+1)%25)==0:
                  self._train_log(loss, example_ct, epoch)

                self.optimizer.zero_grad()
                loss.backward()

                self.optimizer.step()

    def _train_log(self, loss, example_ct, epoch):
      wandb.log({'epoch': epoch, 'loss':loss}, step=example_ct)
      print(f'Loss after ' + str(example_ct).zfill(5) + f' examples: {loss:.3f}')      

    def _check_acc(self, loader):
        msg = 'train' if loader.dataset.train else 'test'     

        print('Checking accuracy on ' +msg+' data')

        num_correct = 0
        num_samples = 0
        self.model.eval()

        with torch.no_grad():
            for x, y in loader:
                x = x.to(device=self.device)
                y = y.to(device=self.device)

                if not self._model_name.startswith('vit'):
                    x = x.repeat(1, 3, 1, 1)
                else:
                    x = x.repeat(1, 3, 8, 8)

                scores = self.model(x)
                _, predictions = scores.max(1)
                num_correct += (predictions == y).sum()
                num_samples += predictions.size(0)

            print(
                f'Got {num_correct}/{num_samples} with accuracy {(float(num_correct) / float(num_samples)) * 100}')
            
            wandb.log({msg+'_accuracy': float(num_correct) / float(num_samples) })

        torch.onnx.export(self.model, x, 'model.onnx')
        wandb.save('model.onnx')
        self.model.train()

    def check_accuracy(self, train_loader, test_loader):
        self._check_acc(train_loader)
        self._check_acc(test_loader)

# %%
class MNIST:
  def __init__(self, batch_size=2):
    self.batch_size=batch_size
    self._train_dataset = datasets.MNIST(root='dataset/', train=True, transform=transforms.ToTensor(), download=True)
    self._train_loader=DataLoader(dataset=self._train_dataset, batch_size=batch_size, shuffle=True)

    self._test_dataset = datasets.MNIST(root='dataset/', train=False, transform=transforms.ToTensor(), download=True)
    self._test_loader=DataLoader(dataset=self._test_dataset, batch_size=batch_size, shuffle=True)


  def train_loader(self):
    return self._train_loader
  
  def test_loader(self):
    return self._test_loader

# %%
learning_rate=0.001
batch_size=2
epochs=2


model = TimmModel('vit_tiny_patch16_224')
model.model_config(learning_rate=learning_rate,batch_size=batch_size,num_epochs=epochs)

mnist = MNIST()


train_loader = mnist.train_loader()
test_loader = mnist.test_loader()

# wandb.watch(model)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to dataset/MNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting dataset/MNIST/raw/train-images-idx3-ubyte.gz to dataset/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to dataset/MNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting dataset/MNIST/raw/train-labels-idx1-ubyte.gz to dataset/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to dataset/MNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting dataset/MNIST/raw/t10k-images-idx3-ubyte.gz to dataset/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to dataset/MNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting dataset/MNIST/raw/t10k-labels-idx1-ubyte.gz to dataset/MNIST/raw
# /usr/local/lib/python3.7/dist-packages/torchvision/datasets/mnist.py:498: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:180.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)

# %%
model.train_model(train_loader=train_loader)
# Out:
# wandb: Currently logged in as: karine_ayrs (use `wandb login --relogin` to force relogin)
#                     Syncing run <strong><a href="https://wandb.ai/karine_ayrs/mnist-classification/runs/2daiiot7" target="_blank">polished-disco-2</a></strong> to <a href="https://wandb.ai/karine_ayrs/mnist-classification" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# Выходные данные были обрезаны до нескольких последних строк (5000).
# Loss after 50250 examples: 0.025
# Loss after 50300 examples: 0.010
# Loss after 50350 examples: 0.828
# Loss after 50400 examples: 0.080
# Loss after 50450 examples: 1.529
# Loss after 50500 examples: 3.604
# Loss after 50550 examples: 0.060
# Loss after 50600 examples: 3.409
# Loss after 50650 examples: 0.056
# Loss after 50700 examples: 0.035
# Loss after 50750 examples: 1.220
# Loss after 50800 examples: 1.069
# Loss after 50850 examples: 0.216
# Loss after 50900 examples: 0.477
# Loss after 50950 examples: 0.171
# Loss after 51000 examples: 0.302
# Loss after 51050 examples: 0.039
# Loss after 51100 examples: 1.819
# Loss after 51150 examples: 0.178
# Loss after 51200 examples: 2.186
# Loss after 51250 examples: 1.175
# Loss after 51300 examples: 0.020
# Loss after 51350 examples: 0.283
# Loss after 51400 examples: 0.062
# Loss after 51450 examples: 0.014
# Loss after 51500 examples: 0.471
# Loss after 51550 examples: 0.361
# Loss after 51600 examples: 0.198
# Loss after 51650 examples: 0.600
# Loss after 51700 examples: 0.487
# Loss after 51750 examples: 0.073
# Loss after 51800 examples: 0.049
# Loss after 51850 examples: 1.248
# Loss after 51900 examples: 0.731
# Loss after 51950 examples: 0.013
# Loss after 52000 examples: 0.150
# Loss after 52050 examples: 0.928
# Loss after 52100 examples: 0.391
# Loss after 52150 examples: 0.308
# Loss after 52200 examples: 0.261
# Loss after 52250 examples: 0.208
# Loss after 52300 examples: 0.162
# Loss after 52350 examples: 0.030
# Loss after 52400 examples: 0.036
# Loss after 52450 examples: 0.335
# Loss after 52500 examples: 0.101
# Loss after 52550 examples: 0.287
# Loss after 52600 examples: 0.214
# Loss after 52650 examples: 0.207
# Loss after 52700 examples: 0.129
# Loss after 52750 examples: 0.812
# Loss after 52800 examples: 1.261
# Loss after 52850 examples: 1.917
# Loss after 52900 examples: 0.601
# Loss after 52950 examples: 0.563
# Loss after 53000 examples: 0.177
# Loss after 53050 examples: 0.003
# Loss after 53100 examples: 0.181
# Loss after 53150 examples: 0.022
# Loss after 53200 examples: 0.250
# Loss after 53250 examples: 0.131
# Loss after 53300 examples: 0.105
# Loss after 53350 examples: 0.063
# Loss after 53400 examples: 1.191
# Loss after 53450 examples: 1.216
# Loss after 53500 examples: 2.451
# Loss after 53550 examples: 0.046
# Loss after 53600 examples: 0.602
# Loss after 53650 examples: 1.068
# Loss after 53700 examples: 0.099
# Loss after 53750 examples: 0.038
# Loss after 53800 examples: 0.501
# Loss after 53850 examples: 0.985
# Loss after 53900 examples: 0.249
# Loss after 53950 examples: 0.186
# Loss after 54000 examples: 0.033
# Loss after 54050 examples: 0.051
# Loss after 54100 examples: 1.236
# Loss after 54150 examples: 0.094
# Loss after 54200 examples: 0.175
# Loss after 54250 examples: 0.172
# Loss after 54300 examples: 1.851
# Loss after 54350 examples: 0.999
# Loss after 54400 examples: 0.038
# Loss after 54450 examples: 0.164
# Loss after 54500 examples: 0.117
# Loss after 54550 examples: 1.201
# Loss after 54600 examples: 1.270
# Loss after 54650 examples: 0.557
# Loss after 54700 examples: 0.891
# Loss after 54750 examples: 1.357
# Loss after 54800 examples: 0.697
# Loss after 54850 examples: 0.204
# Loss after 54900 examples: 0.838
# Loss after 54950 examples: 0.220
# Loss after 55000 examples: 2.840
# Loss after 55050 examples: 1.721
# Loss after 55100 examples: 0.033
# Loss after 55150 examples: 0.651
# Loss after 55200 examples: 0.308
# Loss after 55250 examples: 2.452
# Loss after 55300 examples: 0.538
# Loss after 55350 examples: 1.119
# Loss after 55400 examples: 1.035
# Loss after 55450 examples: 0.662
# Loss after 55500 examples: 0.095
# Loss after 55550 examples: 0.431
# Loss after 55600 examples: 0.048
# Loss after 55650 examples: 4.095
# Loss after 55700 examples: 0.309
# Loss after 55750 examples: 1.275
# Loss after 55800 examples: 0.701
# Loss after 55850 examples: 0.193
# Loss after 55900 examples: 1.764
# Loss after 55950 examples: 0.310
# Loss after 56000 examples: 0.441
# Loss after 56050 examples: 0.556
# Loss after 56100 examples: 0.447
# Loss after 56150 examples: 0.181
# Loss after 56200 examples: 0.674
# Loss after 56250 examples: 0.061
# Loss after 56300 examples: 2.301
# Loss after 56350 examples: 0.113
# Loss after 56400 examples: 1.266
# Loss after 56450 examples: 0.344
# Loss after 56500 examples: 0.035
# Loss after 56550 examples: 0.858
# Loss after 56600 examples: 0.750
# Loss after 56650 examples: 0.046
# Loss after 56700 examples: 2.549
# Loss after 56750 examples: 0.057
# Loss after 56800 examples: 0.151
# Loss after 56850 examples: 0.339
# Loss after 56900 examples: 0.221
# Loss after 56950 examples: 0.216
# Loss after 57000 examples: 0.848
# Loss after 57050 examples: 0.105
# Loss after 57100 examples: 0.160
# Loss after 57150 examples: 0.389
# Loss after 57200 examples: 0.390
# Loss after 57250 examples: 0.259
# Loss after 57300 examples: 0.087
# Loss after 57350 examples: 0.301
# Loss after 57400 examples: 0.537
# Loss after 57450 examples: 0.090
# Loss after 57500 examples: 0.065
# Loss after 57550 examples: 1.043
# Loss after 57600 examples: 1.102
# Loss after 57650 examples: 0.186
# Loss after 57700 examples: 0.016
# Loss after 57750 examples: 0.612
# Loss after 57800 examples: 0.001
# Loss after 57850 examples: 0.020
# Loss after 57900 examples: 0.864
# Loss after 57950 examples: 0.282
# Loss after 58000 examples: 0.603
# Loss after 58050 examples: 0.598
# Loss after 58100 examples: 1.433
# Loss after 58150 examples: 0.244
# Loss after 58200 examples: 0.050
# Loss after 58250 examples: 0.275
# Loss after 58300 examples: 1.487
# Loss after 58350 examples: 1.405
# Loss after 58400 examples: 0.340
# Loss after 58450 examples: 0.010
# Loss after 58500 examples: 0.700
# Loss after 58550 examples: 0.613
# Loss after 58600 examples: 0.486
# Loss after 58650 examples: 0.279
# Loss after 58700 examples: 0.795
# Loss after 58750 examples: 0.133
# Loss after 58800 examples: 0.088
# Loss after 58850 examples: 0.216
# Loss after 58900 examples: 0.009
# Loss after 58950 examples: 2.451
# Loss after 59000 examples: 0.220
# Loss after 59050 examples: 0.127
# Loss after 59100 examples: 1.044
# Loss after 59150 examples: 0.044
# Loss after 59200 examples: 0.185
# Loss after 59250 examples: 0.253
# Loss after 59300 examples: 1.188
# Loss after 59350 examples: 0.002
# Loss after 59400 examples: 1.800
# Loss after 59450 examples: 0.076
# Loss after 59500 examples: 0.019
# Loss after 59550 examples: 1.756
# Loss after 59600 examples: 0.031
# Loss after 59650 examples: 5.347
# Loss after 59700 examples: 1.754
# Loss after 59750 examples: 0.250
# Loss after 59800 examples: 0.124
# Loss after 59850 examples: 0.344
# Loss after 59900 examples: 0.283
# Loss after 59950 examples: 0.939
# Loss after 60000 examples: 4.724
# epoch:2
# Loss after 60050 examples: 3.703
# Loss after 60100 examples: 1.036
# Loss after 60150 examples: 0.615
# Loss after 60200 examples: 0.097
# Loss after 60250 examples: 1.344
# Loss after 60300 examples: 0.069
# Loss after 60350 examples: 0.020
# Loss after 60400 examples: 2.401
# Loss after 60450 examples: 2.218
# Loss after 60500 examples: 0.063
# Loss after 60550 examples: 0.177
# Loss after 60600 examples: 0.164
# Loss after 60650 examples: 0.536
# Loss after 60700 examples: 2.755
# Loss after 60750 examples: 0.049
# Loss after 60800 examples: 0.656
# Loss after 60850 examples: 0.251
# Loss after 60900 examples: 0.009
# Loss after 60950 examples: 3.356
# Loss after 61000 examples: 0.644
# Loss after 61050 examples: 0.093
# Loss after 61100 examples: 0.717
# Loss after 61150 examples: 0.559
# Loss after 61200 examples: 0.845
# Loss after 61250 examples: 0.472
# Loss after 61300 examples: 0.724
# Loss after 61350 examples: 0.365
# Loss after 61400 examples: 1.384
# Loss after 61450 examples: 0.914
# Loss after 61500 examples: 0.354
# Loss after 61550 examples: 0.260
# Loss after 61600 examples: 0.288
# Loss after 61650 examples: 0.205
# Loss after 61700 examples: 0.132
# Loss after 61750 examples: 0.343
# Loss after 61800 examples: 0.188
# Loss after 61850 examples: 0.038
# Loss after 61900 examples: 0.091
# Loss after 61950 examples: 0.041
# Loss after 62000 examples: 0.129
# Loss after 62050 examples: 0.090
# Loss after 62100 examples: 0.016
# Loss after 62150 examples: 0.036
# Loss after 62200 examples: 0.729
# Loss after 62250 examples: 0.006
# Loss after 62300 examples: 0.178
# Loss after 62350 examples: 0.636
# Loss after 62400 examples: 0.382
# Loss after 62450 examples: 0.186
# Loss after 62500 examples: 0.049
# Loss after 62550 examples: 0.544
# Loss after 62600 examples: 0.226
# Loss after 62650 examples: 0.661
# Loss after 62700 examples: 1.303
# Loss after 62750 examples: 0.548
# Loss after 62800 examples: 0.576
# Loss after 62850 examples: 1.206
# Loss after 62900 examples: 0.593
# Loss after 62950 examples: 0.265
# Loss after 63000 examples: 1.168
# Loss after 63050 examples: 0.422
# Loss after 63100 examples: 0.246
# Loss after 63150 examples: 2.203
# Loss after 63200 examples: 1.037
# Loss after 63250 examples: 0.011
# Loss after 63300 examples: 0.210
# Loss after 63350 examples: 0.574
# Loss after 63400 examples: 0.318
# Loss after 63450 examples: 0.892
# Loss after 63500 examples: 0.335
# Loss after 63550 examples: 1.165
# Loss after 63600 examples: 0.218
# Loss after 63650 examples: 1.252
# Loss after 63700 examples: 0.154
# Loss after 63750 examples: 0.036
# Loss after 63800 examples: 0.595
# Loss after 63850 examples: 0.053
# Loss after 63900 examples: 0.193
# Loss after 63950 examples: 0.553
# Loss after 64000 examples: 0.442
# Loss after 64050 examples: 0.465
# Loss after 64100 examples: 0.042
# Loss after 64150 examples: 0.722
# Loss after 64200 examples: 0.597
# Loss after 64250 examples: 0.186
# Loss after 64300 examples: 1.009
# Loss after 64350 examples: 2.308
# Loss after 64400 examples: 1.256
# Loss after 64450 examples: 2.383
# Loss after 64500 examples: 0.633
# Loss after 64550 examples: 0.872
# Loss after 64600 examples: 0.897
# Loss after 64650 examples: 0.019
# Loss after 64700 examples: 0.406
# Loss after 64750 examples: 1.495
# Loss after 64800 examples: 0.115
# Loss after 64850 examples: 1.156
# Loss after 64900 examples: 0.552
# Loss after 64950 examples: 0.400
# Loss after 65000 examples: 0.452
# Loss after 65050 examples: 2.324
# Loss after 65100 examples: 0.205
# Loss after 65150 examples: 0.715
# Loss after 65200 examples: 0.403
# Loss after 65250 examples: 0.376
# Loss after 65300 examples: 0.209
# Loss after 65350 examples: 0.027
# Loss after 65400 examples: 0.397
# Loss after 65450 examples: 0.111
# Loss after 65500 examples: 0.599
# Loss after 65550 examples: 0.537
# Loss after 65600 examples: 2.949
# Loss after 65650 examples: 0.113
# Loss after 65700 examples: 0.138
# Loss after 65750 examples: 0.239
# Loss after 65800 examples: 0.688
# Loss after 65850 examples: 0.128
# Loss after 65900 examples: 0.101
# Loss after 65950 examples: 0.749
# Loss after 66000 examples: 1.594
# Loss after 66050 examples: 0.025
# Loss after 66100 examples: 0.231
# Loss after 66150 examples: 0.404
# Loss after 66200 examples: 0.022
# Loss after 66250 examples: 0.442
# Loss after 66300 examples: 0.354
# Loss after 66350 examples: 0.063
# Loss after 66400 examples: 1.095
# Loss after 66450 examples: 0.114
# Loss after 66500 examples: 0.382
# Loss after 66550 examples: 0.193
# Loss after 66600 examples: 0.044
# Loss after 66650 examples: 0.043
# Loss after 66700 examples: 0.052
# Loss after 66750 examples: 0.855
# Loss after 66800 examples: 1.860
# Loss after 66850 examples: 0.157
# Loss after 66900 examples: 1.188
# Loss after 66950 examples: 0.036
# Loss after 67000 examples: 0.012
# Loss after 67050 examples: 0.594
# Loss after 67100 examples: 1.109
# Loss after 67150 examples: 0.567
# Loss after 67200 examples: 0.625
# Loss after 67250 examples: 0.467
# Loss after 67300 examples: 0.152
# Loss after 67350 examples: 0.201
# Loss after 67400 examples: 0.252
# Loss after 67450 examples: 0.016
# Loss after 67500 examples: 0.150
# Loss after 67550 examples: 0.471
# Loss after 67600 examples: 0.060
# Loss after 67650 examples: 0.211
# Loss after 67700 examples: 0.411
# Loss after 67750 examples: 0.436
# Loss after 67800 examples: 0.285
# Loss after 67850 examples: 0.764
# Loss after 67900 examples: 2.875
# Loss after 67950 examples: 1.621
# Loss after 68000 examples: 0.478
# Loss after 68050 examples: 0.057
# Loss after 68100 examples: 2.138
# Loss after 68150 examples: 0.564
# Loss after 68200 examples: 0.014
# Loss after 68250 examples: 1.353
# Loss after 68300 examples: 0.581
# Loss after 68350 examples: 0.151
# Loss after 68400 examples: 1.736
# Loss after 68450 examples: 0.854
# Loss after 68500 examples: 0.055
# Loss after 68550 examples: 2.250
# Loss after 68600 examples: 0.052
# Loss after 68650 examples: 0.713
# Loss after 68700 examples: 0.386
# Loss after 68750 examples: 1.794
# Loss after 68800 examples: 1.435
# Loss after 68850 examples: 0.188
# Loss after 68900 examples: 0.116
# Loss after 68950 examples: 1.072
# Loss after 69000 examples: 0.080
# Loss after 69050 examples: 0.827
# Loss after 69100 examples: 0.099
# Loss after 69150 examples: 1.658
# Loss after 69200 examples: 0.274
# Loss after 69250 examples: 0.053
# Loss after 69300 examples: 0.232
# Loss after 69350 examples: 0.023
# Loss after 69400 examples: 0.610
# Loss after 69450 examples: 0.086
# Loss after 69500 examples: 0.687
# Loss after 69550 examples: 0.228
# Loss after 69600 examples: 0.013
# Loss after 69650 examples: 0.056
# Loss after 69700 examples: 0.831
# Loss after 69750 examples: 0.245
# Loss after 69800 examples: 0.032
# Loss after 69850 examples: 0.026
# Loss after 69900 examples: 0.530
# Loss after 69950 examples: 0.938
# Loss after 70000 examples: 0.723
# Loss after 70050 examples: 0.428
# Loss after 70100 examples: 1.507
# Loss after 70150 examples: 1.454
# Loss after 70200 examples: 0.233
# Loss after 70250 examples: 0.079
# Loss after 70300 examples: 2.019
# Loss after 70350 examples: 0.257
# Loss after 70400 examples: 1.223
# Loss after 70450 examples: 0.305
# Loss after 70500 examples: 0.704
# Loss after 70550 examples: 0.752
# Loss after 70600 examples: 0.953
# Loss after 70650 examples: 3.621
# Loss after 70700 examples: 0.605
# Loss after 70750 examples: 3.499
# Loss after 70800 examples: 1.300
# Loss after 70850 examples: 1.234
# Loss after 70900 examples: 1.440
# Loss after 70950 examples: 0.674
# Loss after 71000 examples: 0.564
# Loss after 71050 examples: 0.037
# Loss after 71100 examples: 0.264
# Loss after 71150 examples: 2.895
# Loss after 71200 examples: 0.407
# Loss after 71250 examples: 0.397
# Loss after 71300 examples: 0.660
# Loss after 71350 examples: 0.692
# Loss after 71400 examples: 0.382
# Loss after 71450 examples: 0.392
# Loss after 71500 examples: 0.522
# Loss after 71550 examples: 1.564
# Loss after 71600 examples: 0.032
# Loss after 71650 examples: 0.617
# Loss after 71700 examples: 0.577
# Loss after 71750 examples: 0.069
# Loss after 71800 examples: 0.235
# Loss after 71850 examples: 0.614
# Loss after 71900 examples: 0.523
# Loss after 71950 examples: 0.105
# Loss after 72000 examples: 1.001
# Loss after 72050 examples: 0.048
# Loss after 72100 examples: 2.080
# Loss after 72150 examples: 0.390
# Loss after 72200 examples: 0.343
# Loss after 72250 examples: 0.402
# Loss after 72300 examples: 0.852
# Loss after 72350 examples: 0.179
# Loss after 72400 examples: 0.015
# Loss after 72450 examples: 1.447
# Loss after 72500 examples: 0.458
# Loss after 72550 examples: 0.006
# Loss after 72600 examples: 0.284
# Loss after 72650 examples: 0.520
# Loss after 72700 examples: 0.264
# Loss after 72750 examples: 0.068
# Loss after 72800 examples: 0.013
# Loss after 72850 examples: 0.298
# Loss after 72900 examples: 1.125
# Loss after 72950 examples: 0.369
# Loss after 73000 examples: 0.104
# Loss after 73050 examples: 0.761
# Loss after 73100 examples: 2.509
# Loss after 73150 examples: 0.212
# Loss after 73200 examples: 1.201
# Loss after 73250 examples: 2.811
# Loss after 73300 examples: 2.563
# Loss after 73350 examples: 0.464
# Loss after 73400 examples: 0.036
# Loss after 73450 examples: 1.340
# Loss after 73500 examples: 0.361
# Loss after 73550 examples: 2.082
# Loss after 73600 examples: 1.388
# Loss after 73650 examples: 1.903
# Loss after 73700 examples: 0.390
# Loss after 73750 examples: 0.094
# Loss after 73800 examples: 0.398
# Loss after 73850 examples: 1.440
# Loss after 73900 examples: 0.065
# Loss after 73950 examples: 2.533
# Loss after 74000 examples: 1.685
# Loss after 74050 examples: 0.143
# Loss after 74100 examples: 0.211
# Loss after 74150 examples: 1.505
# Loss after 74200 examples: 0.327
# Loss after 74250 examples: 1.794
# Loss after 74300 examples: 0.036
# Loss after 74350 examples: 0.607
# Loss after 74400 examples: 0.864
# Loss after 74450 examples: 0.519
# Loss after 74500 examples: 0.792
# Loss after 74550 examples: 0.519
# Loss after 74600 examples: 0.155
# Loss after 74650 examples: 0.204
# Loss after 74700 examples: 0.782
# Loss after 74750 examples: 1.322
# Loss after 74800 examples: 0.385
# Loss after 74850 examples: 0.525
# Loss after 74900 examples: 0.357
# Loss after 74950 examples: 1.010
# Loss after 75000 examples: 0.526
# Loss after 75050 examples: 0.316
# Loss after 75100 examples: 0.188
# Loss after 75150 examples: 0.386
# Loss after 75200 examples: 0.302
# Loss after 75250 examples: 0.413
# Loss after 75300 examples: 0.121
# Loss after 75350 examples: 0.345
# Loss after 75400 examples: 0.273
# Loss after 75450 examples: 1.299
# Loss after 75500 examples: 0.243
# Loss after 75550 examples: 1.154
# Loss after 75600 examples: 0.099
# Loss after 75650 examples: 0.015
# Loss after 75700 examples: 2.755
# Loss after 75750 examples: 0.160
# Loss after 75800 examples: 0.322
# Loss after 75850 examples: 0.302
# Loss after 75900 examples: 0.801
# Loss after 75950 examples: 0.728
# Loss after 76000 examples: 0.062
# Loss after 76050 examples: 0.549
# Loss after 76100 examples: 1.059
# Loss after 76150 examples: 0.756
# Loss after 76200 examples: 3.213
# Loss after 76250 examples: 0.574
# Loss after 76300 examples: 0.151
# Loss after 76350 examples: 2.239
# Loss after 76400 examples: 0.202
# Loss after 76450 examples: 1.224
# Loss after 76500 examples: 0.128
# Loss after 76550 examples: 1.196
# Loss after 76600 examples: 1.187
# Loss after 76650 examples: 2.522
# Loss after 76700 examples: 0.077
# Loss after 76750 examples: 0.807
# Loss after 76800 examples: 0.327
# Loss after 76850 examples: 1.047
# Loss after 76900 examples: 1.637
# Loss after 76950 examples: 0.077
# Loss after 77000 examples: 0.168
# Loss after 77050 examples: 1.591
# Loss after 77100 examples: 2.101
# Loss after 77150 examples: 1.342
# Loss after 77200 examples: 0.313
# Loss after 77250 examples: 0.168
# Loss after 77300 examples: 1.063
# Loss after 77350 examples: 0.230
# Loss after 77400 examples: 0.011
# Loss after 77450 examples: 0.382
# Loss after 77500 examples: 0.036
# Loss after 77550 examples: 0.061
# Loss after 77600 examples: 0.267
# Loss after 77650 examples: 0.133
# Loss after 77700 examples: 0.253
# Loss after 77750 examples: 0.079
# Loss after 77800 examples: 0.279
# Loss after 77850 examples: 2.944
# Loss after 77900 examples: 0.114
# Loss after 77950 examples: 0.196
# Loss after 78000 examples: 0.238
# Loss after 78050 examples: 3.523
# Loss after 78100 examples: 0.258
# Loss after 78150 examples: 0.728
# Loss after 78200 examples: 0.402
# Loss after 78250 examples: 2.543
# Loss after 78300 examples: 0.719
# Loss after 78350 examples: 0.802
# Loss after 78400 examples: 1.890
# Loss after 78450 examples: 0.117
# Loss after 78500 examples: 0.201
# Loss after 78550 examples: 0.310
# Loss after 78600 examples: 0.695
# Loss after 78650 examples: 0.334
# Loss after 78700 examples: 0.600
# Loss after 78750 examples: 0.225
# Loss after 78800 examples: 0.340
# Loss after 78850 examples: 0.641
# Loss after 78900 examples: 0.324
# Loss after 78950 examples: 0.068
# Loss after 79000 examples: 0.649
# Loss after 79050 examples: 0.007
# Loss after 79100 examples: 0.059
# Loss after 79150 examples: 0.046
# Loss after 79200 examples: 0.957
# Loss after 79250 examples: 0.334
# Loss after 79300 examples: 0.873
# Loss after 79350 examples: 0.142
# Loss after 79400 examples: 0.093
# Loss after 79450 examples: 0.131
# Loss after 79500 examples: 0.461
# Loss after 79550 examples: 0.057
# Loss after 79600 examples: 0.059
# Loss after 79650 examples: 0.009
# Loss after 79700 examples: 0.572
# Loss after 79750 examples: 0.618
# Loss after 79800 examples: 0.267
# Loss after 79850 examples: 0.830
# Loss after 79900 examples: 0.424
# Loss after 79950 examples: 0.061
# Loss after 80000 examples: 0.510
# Loss after 80050 examples: 0.301
# Loss after 80100 examples: 0.044
# Loss after 80150 examples: 0.263
# Loss after 80200 examples: 0.385
# Loss after 80250 examples: 0.237
# Loss after 80300 examples: 0.045
# Loss after 80350 examples: 0.227
# Loss after 80400 examples: 0.009
# Loss after 80450 examples: 0.616
# Loss after 80500 examples: 0.559
# Loss after 80550 examples: 0.084
# Loss after 80600 examples: 1.311
# Loss after 80650 examples: 2.132
# Loss after 80700 examples: 1.711
# Loss after 80750 examples: 0.016
# Loss after 80800 examples: 0.240
# Loss after 80850 examples: 0.022
# Loss after 80900 examples: 0.145
# Loss after 80950 examples: 0.216
# Loss after 81000 examples: 0.008
# Loss after 81050 examples: 0.583
# Loss after 81100 examples: 0.084
# Loss after 81150 examples: 2.017
# Loss after 81200 examples: 0.872
# Loss after 81250 examples: 1.564
# Loss after 81300 examples: 0.310
# Loss after 81350 examples: 0.437
# Loss after 81400 examples: 0.411
# Loss after 81450 examples: 1.755
# Loss after 81500 examples: 0.203
# Loss after 81550 examples: 0.786
# Loss after 81600 examples: 0.665
# Loss after 81650 examples: 0.088
# Loss after 81700 examples: 0.731
# Loss after 81750 examples: 4.431
# Loss after 81800 examples: 0.943
# Loss after 81850 examples: 1.173
# Loss after 81900 examples: 0.743
# Loss after 81950 examples: 0.078
# Loss after 82000 examples: 1.252
# Loss after 82050 examples: 0.420
# Loss after 82100 examples: 0.919
# Loss after 82150 examples: 0.297
# Loss after 82200 examples: 0.059
# Loss after 82250 examples: 0.241
# Loss after 82300 examples: 0.286
# Loss after 82350 examples: 0.026
# Loss after 82400 examples: 0.159
# Loss after 82450 examples: 0.169
# Loss after 82500 examples: 0.624
# Loss after 82550 examples: 0.358
# Loss after 82600 examples: 2.059
# Loss after 82650 examples: 0.051
# Loss after 82700 examples: 0.864
# Loss after 82750 examples: 0.027
# Loss after 82800 examples: 0.168
# Loss after 82850 examples: 0.073
# Loss after 82900 examples: 1.442
# Loss after 82950 examples: 1.762
# Loss after 83000 examples: 0.074
# Loss after 83050 examples: 0.171
# Loss after 83100 examples: 0.685
# Loss after 83150 examples: 3.634
# Loss after 83200 examples: 0.106
# Loss after 83250 examples: 0.362
# Loss after 83300 examples: 0.723
# Loss after 83350 examples: 0.919
# Loss after 83400 examples: 2.400
# Loss after 83450 examples: 2.022
# Loss after 83500 examples: 0.042
# Loss after 83550 examples: 1.672
# Loss after 83600 examples: 1.238
# Loss after 83650 examples: 0.004
# Loss after 83700 examples: 1.475
# Loss after 83750 examples: 0.073
# Loss after 83800 examples: 0.009
# Loss after 83850 examples: 0.345
# Loss after 83900 examples: 0.606
# Loss after 83950 examples: 2.312
# Loss after 84000 examples: 0.435
# Loss after 84050 examples: 0.671
# Loss after 84100 examples: 0.241
# Loss after 84150 examples: 0.006
# Loss after 84200 examples: 0.050
# Loss after 84250 examples: 0.220
# Loss after 84300 examples: 0.844
# Loss after 84350 examples: 0.070
# Loss after 84400 examples: 0.556
# Loss after 84450 examples: 0.889
# Loss after 84500 examples: 0.306
# Loss after 84550 examples: 0.023
# Loss after 84600 examples: 0.047
# Loss after 84650 examples: 0.618
# Loss after 84700 examples: 0.319
# Loss after 84750 examples: 0.420
# Loss after 84800 examples: 0.600
# Loss after 84850 examples: 0.251
# Loss after 84900 examples: 0.401
# Loss after 84950 examples: 0.064
# Loss after 85000 examples: 0.349
# Loss after 85050 examples: 0.316
# Loss after 85100 examples: 1.308
# Loss after 85150 examples: 0.009
# Loss after 85200 examples: 0.463
# Loss after 85250 examples: 0.181
# Loss after 85300 examples: 0.459
# Loss after 85350 examples: 0.198
# Loss after 85400 examples: 0.492
# Loss after 85450 examples: 0.355
# Loss after 85500 examples: 0.178
# Loss after 85550 examples: 0.309
# Loss after 85600 examples: 0.282
# Loss after 85650 examples: 0.071
# Loss after 85700 examples: 0.524
# Loss after 85750 examples: 0.175
# Loss after 85800 examples: 0.117
# Loss after 85850 examples: 1.239
# Loss after 85900 examples: 0.025
# Loss after 85950 examples: 0.316
# Loss after 86000 examples: 0.033
# Loss after 86050 examples: 0.522
# Loss after 86100 examples: 0.172
# Loss after 86150 examples: 0.706
# Loss after 86200 examples: 2.324
# Loss after 86250 examples: 0.688
# Loss after 86300 examples: 0.009
# Loss after 86350 examples: 0.271
# Loss after 86400 examples: 2.127
# Loss after 86450 examples: 0.163
# Loss after 86500 examples: 0.688
# Loss after 86550 examples: 0.039
# Loss after 86600 examples: 0.145
# Loss after 86650 examples: 0.028
# Loss after 86700 examples: 0.012
# Loss after 86750 examples: 0.105
# Loss after 86800 examples: 0.599
# Loss after 86850 examples: 1.285
# Loss after 86900 examples: 1.015
# Loss after 86950 examples: 0.302
# Loss after 87000 examples: 0.203
# Loss after 87050 examples: 0.273
# Loss after 87100 examples: 0.760
# Loss after 87150 examples: 1.588
# Loss after 87200 examples: 0.324
# Loss after 87250 examples: 0.339
# Loss after 87300 examples: 0.996
# Loss after 87350 examples: 0.115
# Loss after 87400 examples: 0.138
# Loss after 87450 examples: 1.313
# Loss after 87500 examples: 0.254
# Loss after 87550 examples: 0.451
# Loss after 87600 examples: 0.083
# Loss after 87650 examples: 1.190
# Loss after 87700 examples: 0.262
# Loss after 87750 examples: 0.039
# Loss after 87800 examples: 0.417
# Loss after 87850 examples: 2.059
# Loss after 87900 examples: 3.555
# Loss after 87950 examples: 0.004
# Loss after 88000 examples: 0.856
# Loss after 88050 examples: 0.208
# Loss after 88100 examples: 0.077
# Loss after 88150 examples: 1.319
# Loss after 88200 examples: 0.766
# Loss after 88250 examples: 0.645
# Loss after 88300 examples: 3.626
# Loss after 88350 examples: 0.327
# Loss after 88400 examples: 0.052
# Loss after 88450 examples: 2.662
# Loss after 88500 examples: 0.078
# Loss after 88550 examples: 0.040
# Loss after 88600 examples: 0.709
# Loss after 88650 examples: 0.362
# Loss after 88700 examples: 0.215
# Loss after 88750 examples: 0.679
# Loss after 88800 examples: 1.491
# Loss after 88850 examples: 0.753
# Loss after 88900 examples: 0.228
# Loss after 88950 examples: 2.156
# Loss after 89000 examples: 0.056
# Loss after 89050 examples: 0.018
# Loss after 89100 examples: 0.158
# Loss after 89150 examples: 0.897
# Loss after 89200 examples: 0.647
# Loss after 89250 examples: 0.852
# Loss after 89300 examples: 0.127
# Loss after 89350 examples: 0.086
# Loss after 89400 examples: 3.031
# Loss after 89450 examples: 0.163
# Loss after 89500 examples: 0.059
# Loss after 89550 examples: 1.322
# Loss after 89600 examples: 1.125
# Loss after 89650 examples: 0.912
# Loss after 89700 examples: 0.641
# Loss after 89750 examples: 0.068
# Loss after 89800 examples: 0.573
# Loss after 89850 examples: 0.124
# Loss after 89900 examples: 0.326
# Loss after 89950 examples: 0.702
# Loss after 90000 examples: 0.234
# Loss after 90050 examples: 0.491
# Loss after 90100 examples: 0.006
# Loss after 90150 examples: 0.459
# Loss after 90200 examples: 0.235
# Loss after 90250 examples: 0.858
# Loss after 90300 examples: 0.575
# Loss after 90350 examples: 1.192
# Loss after 90400 examples: 0.146
# Loss after 90450 examples: 0.263
# Loss after 90500 examples: 0.073
# Loss after 90550 examples: 0.840
# Loss after 90600 examples: 0.016
# Loss after 90650 examples: 3.402
# Loss after 90700 examples: 0.134
# Loss after 90750 examples: 0.887
# Loss after 90800 examples: 0.899
# Loss after 90850 examples: 0.190
# Loss after 90900 examples: 0.707
# Loss after 90950 examples: 0.348
# Loss after 91000 examples: 2.136
# Loss after 91050 examples: 1.157
# Loss after 91100 examples: 0.139
# Loss after 91150 examples: 0.165
# Loss after 91200 examples: 2.088
# Loss after 91250 examples: 1.747
# Loss after 91300 examples: 0.066
# Loss after 91350 examples: 0.782
# Loss after 91400 examples: 0.172
# Loss after 91450 examples: 0.135
# Loss after 91500 examples: 2.901
# Loss after 91550 examples: 1.008
# Loss after 91600 examples: 0.535
# Loss after 91650 examples: 0.143
# Loss after 91700 examples: 0.102
# Loss after 91750 examples: 0.451
# Loss after 91800 examples: 0.054
# Loss after 91850 examples: 0.051
# Loss after 91900 examples: 0.346
# Loss after 91950 examples: 0.695
# Loss after 92000 examples: 0.707
# Loss after 92050 examples: 0.356
# Loss after 92100 examples: 0.162
# Loss after 92150 examples: 0.182
# Loss after 92200 examples: 0.312
# Loss after 92250 examples: 0.096
# Loss after 92300 examples: 0.228
# Loss after 92350 examples: 0.097
# Loss after 92400 examples: 0.116
# Loss after 92450 examples: 0.223
# Loss after 92500 examples: 0.124
# Loss after 92550 examples: 1.863
# Loss after 92600 examples: 0.006
# Loss after 92650 examples: 0.080
# Loss after 92700 examples: 1.655
# Loss after 92750 examples: 0.615
# Loss after 92800 examples: 0.004
# Loss after 92850 examples: 2.523
# Loss after 92900 examples: 0.003
# Loss after 92950 examples: 0.286
# Loss after 93000 examples: 0.101
# Loss after 93050 examples: 6.648
# Loss after 93100 examples: 0.318
# Loss after 93150 examples: 0.083
# Loss after 93200 examples: 0.028
# Loss after 93250 examples: 2.038
# Loss after 93300 examples: 0.059
# Loss after 93350 examples: 0.231
# Loss after 93400 examples: 0.000
# Loss after 93450 examples: 0.025
# Loss after 93500 examples: 0.464
# Loss after 93550 examples: 1.206
# Loss after 93600 examples: 0.478
# Loss after 93650 examples: 0.109
# Loss after 93700 examples: 0.002
# Loss after 93750 examples: 0.006
# Loss after 93800 examples: 0.091
# Loss after 93850 examples: 0.115
# Loss after 93900 examples: 0.379
# Loss after 93950 examples: 0.014
# Loss after 94000 examples: 0.005
# Loss after 94050 examples: 0.118
# Loss after 94100 examples: 0.266
# Loss after 94150 examples: 0.456
# Loss after 94200 examples: 0.094
# Loss after 94250 examples: 0.353
# Loss after 94300 examples: 0.855
# Loss after 94350 examples: 0.018
# Loss after 94400 examples: 0.047
# Loss after 94450 examples: 0.098
# Loss after 94500 examples: 0.150
# Loss after 94550 examples: 3.651
# Loss after 94600 examples: 0.807
# Loss after 94650 examples: 2.131
# Loss after 94700 examples: 0.904
# Loss after 94750 examples: 0.427
# Loss after 94800 examples: 0.232
# Loss after 94850 examples: 0.045
# Loss after 94900 examples: 2.201
# Loss after 94950 examples: 0.151
# Loss after 95000 examples: 0.035
# Loss after 95050 examples: 0.067
# Loss after 95100 examples: 0.173
# Loss after 95150 examples: 1.951
# Loss after 95200 examples: 0.718
# Loss after 95250 examples: 1.567
# Loss after 95300 examples: 0.536
# Loss after 95350 examples: 1.198
# Loss after 95400 examples: 0.384
# Loss after 95450 examples: 0.179
# Loss after 95500 examples: 0.291
# Loss after 95550 examples: 1.844
# Loss after 95600 examples: 0.382
# Loss after 95650 examples: 1.002
# Loss after 95700 examples: 0.371
# Loss after 95750 examples: 0.122
# Loss after 95800 examples: 0.044
# Loss after 95850 examples: 0.002
# Loss after 95900 examples: 0.440
# Loss after 95950 examples: 0.048
# Loss after 96000 examples: 0.690
# Loss after 96050 examples: 0.056
# Loss after 96100 examples: 0.569
# Loss after 96150 examples: 0.130
# Loss after 96200 examples: 0.863
# Loss after 96250 examples: 0.032
# Loss after 96300 examples: 0.589
# Loss after 96350 examples: 0.608
# Loss after 96400 examples: 0.052
# Loss after 96450 examples: 2.079
# Loss after 96500 examples: 1.601
# Loss after 96550 examples: 0.716
# Loss after 96600 examples: 1.270
# Loss after 96650 examples: 0.137
# Loss after 96700 examples: 1.611
# Loss after 96750 examples: 0.293
# Loss after 96800 examples: 3.387
# Loss after 96850 examples: 0.329
# Loss after 96900 examples: 0.117
# Loss after 96950 examples: 0.275
# Loss after 97000 examples: 1.753
# Loss after 97050 examples: 1.094
# Loss after 97100 examples: 0.072
# Loss after 97150 examples: 3.294
# Loss after 97200 examples: 0.337
# Loss after 97250 examples: 0.152
# Loss after 97300 examples: 0.484
# Loss after 97350 examples: 2.210
# Loss after 97400 examples: 0.318
# Loss after 97450 examples: 3.608
# Loss after 97500 examples: 0.356
# Loss after 97550 examples: 0.725
# Loss after 97600 examples: 0.009
# Loss after 97650 examples: 0.076
# Loss after 97700 examples: 1.495
# Loss after 97750 examples: 0.264
# Loss after 97800 examples: 0.259
# Loss after 97850 examples: 1.107
# Loss after 97900 examples: 0.590
# Loss after 97950 examples: 3.084
# Loss after 98000 examples: 0.239
# Loss after 98050 examples: 0.295
# Loss after 98100 examples: 0.293
# Loss after 98150 examples: 1.727
# Loss after 98200 examples: 0.131
# Loss after 98250 examples: 1.017
# Loss after 98300 examples: 4.306
# Loss after 98350 examples: 0.256
# Loss after 98400 examples: 3.340
# Loss after 98450 examples: 0.553
# Loss after 98500 examples: 0.994
# Loss after 98550 examples: 0.667
# Loss after 98600 examples: 0.275
# Loss after 98650 examples: 1.223
# Loss after 98700 examples: 0.519
# Loss after 98750 examples: 1.362
# Loss after 98800 examples: 0.269
# Loss after 98850 examples: 2.163
# Loss after 98900 examples: 1.480
# Loss after 98950 examples: 0.638
# Loss after 99000 examples: 1.061
# Loss after 99050 examples: 0.055
# Loss after 99100 examples: 1.097
# Loss after 99150 examples: 0.064
# Loss after 99200 examples: 1.479
# Loss after 99250 examples: 4.290
# Loss after 99300 examples: 0.758
# Loss after 99350 examples: 0.854
# Loss after 99400 examples: 1.221
# Loss after 99450 examples: 0.076
# Loss after 99500 examples: 0.559
# Loss after 99550 examples: 0.406
# Loss after 99600 examples: 0.072
# Loss after 99650 examples: 1.890
# Loss after 99700 examples: 0.300
# Loss after 99750 examples: 0.039
# Loss after 99800 examples: 0.036
# Loss after 99850 examples: 1.130
# Loss after 99900 examples: 0.409
# Loss after 99950 examples: 1.232
# Loss after 100000 examples: 0.204
# Loss after 100050 examples: 0.434
# Loss after 100100 examples: 0.170
# Loss after 100150 examples: 0.252
# Loss after 100200 examples: 0.865
# Loss after 100250 examples: 0.200
# Loss after 100300 examples: 0.158
# Loss after 100350 examples: 0.099
# Loss after 100400 examples: 0.391
# Loss after 100450 examples: 0.359
# Loss after 100500 examples: 1.208
# Loss after 100550 examples: 1.643
# Loss after 100600 examples: 1.244
# Loss after 100650 examples: 0.032
# Loss after 100700 examples: 0.017
# Loss after 100750 examples: 1.357
# Loss after 100800 examples: 0.987
# Loss after 100850 examples: 1.327
# Loss after 100900 examples: 0.391
# Loss after 100950 examples: 0.425
# Loss after 101000 examples: 0.061
# Loss after 101050 examples: 0.164
# Loss after 101100 examples: 2.152
# Loss after 101150 examples: 0.363
# Loss after 101200 examples: 1.365
# Loss after 101250 examples: 1.040
# Loss after 101300 examples: 1.115
# Loss after 101350 examples: 1.124
# Loss after 101400 examples: 0.067
# Loss after 101450 examples: 0.993
# Loss after 101500 examples: 0.001
# Loss after 101550 examples: 0.098
# Loss after 101600 examples: 0.057
# Loss after 101650 examples: 1.767
# Loss after 101700 examples: 0.010
# Loss after 101750 examples: 0.018
# Loss after 101800 examples: 2.662
# Loss after 101850 examples: 0.017
# Loss after 101900 examples: 0.700
# Loss after 101950 examples: 0.818
# Loss after 102000 examples: 0.785
# Loss after 102050 examples: 0.003
# Loss after 102100 examples: 0.199
# Loss after 102150 examples: 0.055
# Loss after 102200 examples: 0.201
# Loss after 102250 examples: 0.109
# Loss after 102300 examples: 0.087
# Loss after 102350 examples: 0.196
# Loss after 102400 examples: 0.202
# Loss after 102450 examples: 0.827
# Loss after 102500 examples: 0.027
# Loss after 102550 examples: 0.027
# Loss after 102600 examples: 0.151
# Loss after 102650 examples: 0.534
# Loss after 102700 examples: 1.115
# Loss after 102750 examples: 0.122
# Loss after 102800 examples: 0.575
# Loss after 102850 examples: 0.123
# Loss after 102900 examples: 2.139
# Loss after 102950 examples: 0.604
# Loss after 103000 examples: 0.030
# Loss after 103050 examples: 1.520
# Loss after 103100 examples: 0.293
# Loss after 103150 examples: 1.114
# Loss after 103200 examples: 0.001
# Loss after 103250 examples: 0.010
# Loss after 103300 examples: 0.064
# Loss after 103350 examples: 0.607
# Loss after 103400 examples: 0.017
# Loss after 103450 examples: 0.709
# Loss after 103500 examples: 0.026
# Loss after 103550 examples: 1.118
# Loss after 103600 examples: 0.036
# Loss after 103650 examples: 0.020
# Loss after 103700 examples: 0.511
# Loss after 103750 examples: 1.501
# Loss after 103800 examples: 0.269
# Loss after 103850 examples: 3.414
# Loss after 103900 examples: 0.193
# Loss after 103950 examples: 0.111
# Loss after 104000 examples: 0.251
# Loss after 104050 examples: 0.117
# Loss after 104100 examples: 0.352
# Loss after 104150 examples: 0.023
# Loss after 104200 examples: 2.225
# Loss after 104250 examples: 0.555
# Loss after 104300 examples: 1.773
# Loss after 104350 examples: 0.137
# Loss after 104400 examples: 0.210
# Loss after 104450 examples: 1.519
# Loss after 104500 examples: 2.450
# Loss after 104550 examples: 0.556
# Loss after 104600 examples: 0.650
# Loss after 104650 examples: 0.167
# Loss after 104700 examples: 0.352
# Loss after 104750 examples: 1.091
# Loss after 104800 examples: 0.238
# Loss after 104850 examples: 1.831
# Loss after 104900 examples: 1.716
# Loss after 104950 examples: 1.342
# Loss after 105000 examples: 0.646
# Loss after 105050 examples: 1.384
# Loss after 105100 examples: 0.609
# Loss after 105150 examples: 0.711
# Loss after 105200 examples: 0.395
# Loss after 105250 examples: 1.137
# Loss after 105300 examples: 0.609
# Loss after 105350 examples: 0.167
# Loss after 105400 examples: 0.137
# Loss after 105450 examples: 0.622
# Loss after 105500 examples: 0.110
# Loss after 105550 examples: 0.061
# Loss after 105600 examples: 0.033
# Loss after 105650 examples: 0.136
# Loss after 105700 examples: 0.753
# Loss after 105750 examples: 0.002
# Loss after 105800 examples: 1.244
# Loss after 105850 examples: 0.107
# Loss after 105900 examples: 0.415
# Loss after 105950 examples: 1.275
# Loss after 106000 examples: 0.643
# Loss after 106050 examples: 0.123
# Loss after 106100 examples: 0.364
# Loss after 106150 examples: 0.031
# Loss after 106200 examples: 0.684
# Loss after 106250 examples: 0.006
# Loss after 106300 examples: 0.980
# Loss after 106350 examples: 0.624
# Loss after 106400 examples: 0.036
# Loss after 106450 examples: 0.432
# Loss after 106500 examples: 1.935
# Loss after 106550 examples: 0.016
# Loss after 106600 examples: 3.751
# Loss after 106650 examples: 0.198
# Loss after 106700 examples: 0.003
# Loss after 106750 examples: 0.140
# Loss after 106800 examples: 0.500
# Loss after 106850 examples: 2.867
# Loss after 106900 examples: 0.015
# Loss after 106950 examples: 0.430
# Loss after 107000 examples: 0.005
# Loss after 107050 examples: 0.692
# Loss after 107100 examples: 0.105
# Loss after 107150 examples: 1.676
# Loss after 107200 examples: 0.014
# Loss after 107250 examples: 0.084
# Loss after 107300 examples: 0.016
# Loss after 107350 examples: 0.770
# Loss after 107400 examples: 0.092
# Loss after 107450 examples: 0.024
# Loss after 107500 examples: 0.141
# Loss after 107550 examples: 0.030
# Loss after 107600 examples: 0.005
# Loss after 107650 examples: 0.527
# Loss after 107700 examples: 0.535
# Loss after 107750 examples: 0.193
# Loss after 107800 examples: 3.389
# Loss after 107850 examples: 2.540
# Loss after 107900 examples: 0.846
# Loss after 107950 examples: 0.080
# Loss after 108000 examples: 0.173
# Loss after 108050 examples: 0.360
# Loss after 108100 examples: 0.024
# Loss after 108150 examples: 0.642
# Loss after 108200 examples: 0.325
# Loss after 108250 examples: 0.122
# Loss after 108300 examples: 0.591
# Loss after 108350 examples: 0.758
# Loss after 108400 examples: 0.080
# Loss after 108450 examples: 1.462
# Loss after 108500 examples: 0.676
# Loss after 108550 examples: 0.187
# Loss after 108600 examples: 0.202
# Loss after 108650 examples: 0.089
# Loss after 108700 examples: 0.548
# Loss after 108750 examples: 0.326
# Loss after 108800 examples: 1.019
# Loss after 108850 examples: 3.254
# Loss after 108900 examples: 5.068
# Loss after 108950 examples: 0.893
# Loss after 109000 examples: 1.420
# Loss after 109050 examples: 0.624
# Loss after 109100 examples: 0.136
# Loss after 109150 examples: 1.634
# Loss after 109200 examples: 0.317
# Loss after 109250 examples: 0.082
# Loss after 109300 examples: 1.150
# Loss after 109350 examples: 0.108
# Loss after 109400 examples: 0.036
# Loss after 109450 examples: 0.523
# Loss after 109500 examples: 0.759
# Loss after 109550 examples: 0.411
# Loss after 109600 examples: 0.166
# Loss after 109650 examples: 0.007
# Loss after 109700 examples: 0.165
# Loss after 109750 examples: 0.171
# Loss after 109800 examples: 0.381
# Loss after 109850 examples: 0.028
# Loss after 109900 examples: 0.027
# Loss after 109950 examples: 0.020
# Loss after 110000 examples: 0.778
# Loss after 110050 examples: 0.245
# Loss after 110100 examples: 0.280
# Loss after 110150 examples: 0.142
# Loss after 110200 examples: 0.028
# Loss after 110250 examples: 0.406
# Loss after 110300 examples: 0.332
# Loss after 110350 examples: 1.830
# Loss after 110400 examples: 0.284
# Loss after 110450 examples: 0.992
# Loss after 110500 examples: 1.865
# Loss after 110550 examples: 0.014
# Loss after 110600 examples: 0.038
# Loss after 110650 examples: 0.009
# Loss after 110700 examples: 0.072
# Loss after 110750 examples: 0.028
# Loss after 110800 examples: 0.030
# Loss after 110850 examples: 0.207
# Loss after 110900 examples: 1.496
# Loss after 110950 examples: 0.087
# Loss after 111000 examples: 1.298
# Loss after 111050 examples: 0.754
# Loss after 111100 examples: 0.755
# Loss after 111150 examples: 0.204
# Loss after 111200 examples: 0.083
# Loss after 111250 examples: 0.040
# Loss after 111300 examples: 0.116
# Loss after 111350 examples: 1.635
# Loss after 111400 examples: 0.519
# Loss after 111450 examples: 0.470
# Loss after 111500 examples: 1.322
# Loss after 111550 examples: 0.339
# Loss after 111600 examples: 0.092
# Loss after 111650 examples: 1.743
# Loss after 111700 examples: 0.900
# Loss after 111750 examples: 0.278
# Loss after 111800 examples: 0.078
# Loss after 111850 examples: 0.019
# Loss after 111900 examples: 0.104
# Loss after 111950 examples: 0.885
# Loss after 112000 examples: 0.182
# Loss after 112050 examples: 0.513
# Loss after 112100 examples: 0.283
# Loss after 112150 examples: 2.070
# Loss after 112200 examples: 0.017
# Loss after 112250 examples: 4.022
# Loss after 112300 examples: 0.373
# Loss after 112350 examples: 0.047
# Loss after 112400 examples: 0.102
# Loss after 112450 examples: 0.132
# Loss after 112500 examples: 0.043
# Loss after 112550 examples: 0.246
# Loss after 112600 examples: 0.071
# Loss after 112650 examples: 0.026
# Loss after 112700 examples: 0.190
# Loss after 112750 examples: 0.030
# Loss after 112800 examples: 0.192
# Loss after 112850 examples: 0.011
# Loss after 112900 examples: 1.695
# Loss after 112950 examples: 0.558
# Loss after 113000 examples: 0.449
# Loss after 113050 examples: 1.067
# Loss after 113100 examples: 0.156
# Loss after 113150 examples: 0.019
# Loss after 113200 examples: 0.173
# Loss after 113250 examples: 0.003
# Loss after 113300 examples: 0.294
# Loss after 113350 examples: 0.168
# Loss after 113400 examples: 2.372
# Loss after 113450 examples: 2.001
# Loss after 113500 examples: 0.038
# Loss after 113550 examples: 0.193
# Loss after 113600 examples: 1.122
# Loss after 113650 examples: 0.259
# Loss after 113700 examples: 0.222
# Loss after 113750 examples: 0.041
# Loss after 113800 examples: 0.553
# Loss after 113850 examples: 0.002
# Loss after 113900 examples: 0.514
# Loss after 113950 examples: 0.007
# Loss after 114000 examples: 1.593
# Loss after 114050 examples: 0.092
# Loss after 114100 examples: 0.242
# Loss after 114150 examples: 0.159
# Loss after 114200 examples: 0.041
# Loss after 114250 examples: 0.061
# Loss after 114300 examples: 0.382
# Loss after 114350 examples: 0.090
# Loss after 114400 examples: 0.517
# Loss after 114450 examples: 0.027
# Loss after 114500 examples: 0.094
# Loss after 114550 examples: 0.103
# Loss after 114600 examples: 0.071
# Loss after 114650 examples: 1.788
# Loss after 114700 examples: 0.495
# Loss after 114750 examples: 0.000
# Loss after 114800 examples: 2.061
# Loss after 114850 examples: 0.127
# Loss after 114900 examples: 0.180
# Loss after 114950 examples: 0.324
# Loss after 115000 examples: 0.358
# Loss after 115050 examples: 0.052
# Loss after 115100 examples: 2.273
# Loss after 115150 examples: 2.486
# Loss after 115200 examples: 0.642
# Loss after 115250 examples: 0.130
# Loss after 115300 examples: 0.062
# Loss after 115350 examples: 1.198
# Loss after 115400 examples: 0.163
# Loss after 115450 examples: 0.255
# Loss after 115500 examples: 0.132
# Loss after 115550 examples: 1.590
# Loss after 115600 examples: 0.316
# Loss after 115650 examples: 0.260
# Loss after 115700 examples: 2.916
# Loss after 115750 examples: 0.385
# Loss after 115800 examples: 0.007
# Loss after 115850 examples: 0.974
# Loss after 115900 examples: 0.013
# Loss after 115950 examples: 0.006
# Loss after 116000 examples: 0.882
# Loss after 116050 examples: 0.281
# Loss after 116100 examples: 0.169
# Loss after 116150 examples: 0.146
# Loss after 116200 examples: 2.158
# Loss after 116250 examples: 1.294
# Loss after 116300 examples: 0.062
# Loss after 116350 examples: 0.046
# Loss after 116400 examples: 0.198
# Loss after 116450 examples: 0.016
# Loss after 116500 examples: 0.822
# Loss after 116550 examples: 3.743
# Loss after 116600 examples: 0.066
# Loss after 116650 examples: 0.140
# Loss after 116700 examples: 0.219
# Loss after 116750 examples: 0.064
# Loss after 116800 examples: 0.140
# Loss after 116850 examples: 0.146
# Loss after 116900 examples: 0.144
# Loss after 116950 examples: 0.002
# Loss after 117000 examples: 0.270
# Loss after 117050 examples: 1.245
# Loss after 117100 examples: 0.028
# Loss after 117150 examples: 0.009
# Loss after 117200 examples: 1.244
# Loss after 117250 examples: 0.047
# Loss after 117300 examples: 0.432
# Loss after 117350 examples: 1.881
# Loss after 117400 examples: 0.793
# Loss after 117450 examples: 0.131
# Loss after 117500 examples: 0.125
# Loss after 117550 examples: 0.022
# Loss after 117600 examples: 0.135
# Loss after 117650 examples: 0.059
# Loss after 117700 examples: 0.194
# Loss after 117750 examples: 0.030
# Loss after 117800 examples: 0.094
# Loss after 117850 examples: 3.525
# Loss after 117900 examples: 1.065
# Loss after 117950 examples: 0.463
# Loss after 118000 examples: 0.397
# Loss after 118050 examples: 0.129
# Loss after 118100 examples: 0.040
# Loss after 118150 examples: 0.074
# Loss after 118200 examples: 0.538
# Loss after 118250 examples: 0.119
# Loss after 118300 examples: 0.009
# Loss after 118350 examples: 0.715
# Loss after 118400 examples: 0.019
# Loss after 118450 examples: 0.285
# Loss after 118500 examples: 0.289
# Loss after 118550 examples: 0.066
# Loss after 118600 examples: 0.805
# Loss after 118650 examples: 1.379
# Loss after 118700 examples: 0.155
# Loss after 118750 examples: 0.808
# Loss after 118800 examples: 0.008
# Loss after 118850 examples: 0.689
# Loss after 118900 examples: 0.067
# Loss after 118950 examples: 0.035
# Loss after 119000 examples: 0.213
# Loss after 119050 examples: 0.820
# Loss after 119100 examples: 0.063
# Loss after 119150 examples: 0.475
# Loss after 119200 examples: 0.633
# Loss after 119250 examples: 0.102
# Loss after 119300 examples: 1.856
# Loss after 119350 examples: 0.093
# Loss after 119400 examples: 0.047
# Loss after 119450 examples: 0.049
# Loss after 119500 examples: 1.234
# Loss after 119550 examples: 0.545
# Loss after 119600 examples: 0.655
# Loss after 119650 examples: 0.302
# Loss after 119700 examples: 0.033
# Loss after 119750 examples: 0.002
# Loss after 119800 examples: 0.183
# Loss after 119850 examples: 1.196
# Loss after 119900 examples: 0.003
# Loss after 119950 examples: 0.205
# Loss after 120000 examples: 0.005
# epoch:3
# Loss after 120050 examples: 0.023
# Loss after 120100 examples: 0.884
# Loss after 120150 examples: 1.001
# Loss after 120200 examples: 1.463
# Loss after 120250 examples: 0.259
# Loss after 120300 examples: 0.614
# Loss after 120350 examples: 0.445
# Loss after 120400 examples: 1.583
# Loss after 120450 examples: 0.153
# Loss after 120500 examples: 0.907
# Loss after 120550 examples: 0.215
# Loss after 120600 examples: 0.044
# Loss after 120650 examples: 0.072
# Loss after 120700 examples: 1.612
# Loss after 120750 examples: 1.197
# Loss after 120800 examples: 0.603
# Loss after 120850 examples: 0.068
# Loss after 120900 examples: 0.624
# Loss after 120950 examples: 2.291
# Loss after 121000 examples: 0.002
# Loss after 121050 examples: 1.209
# Loss after 121100 examples: 0.164
# Loss after 121150 examples: 0.465
# Loss after 121200 examples: 0.914
# Loss after 121250 examples: 2.224
# Loss after 121300 examples: 0.398
# Loss after 121350 examples: 1.088
# Loss after 121400 examples: 0.373
# Loss after 121450 examples: 0.642
# ...
# Loss after 276550 examples: 0.092
# Loss after 276600 examples: 0.023
# Loss after 276650 examples: 0.332
# Loss after 276700 examples: 0.029
# Loss after 276750 examples: 0.100
# Loss after 276800 examples: 0.006
# Loss after 276850 examples: 0.140
# Loss after 276900 examples: 0.017
# Loss after 276950 examples: 0.099
# Loss after 277000 examples: 2.916
# Loss after 277050 examples: 0.084
# Loss after 277100 examples: 0.009
# Loss after 277150 examples: 0.925
# Loss after 277200 examples: 0.009
# Loss after 277250 examples: 3.068
# Loss after 277300 examples: 0.284
# Loss after 277350 examples: 0.078
# Loss after 277400 examples: 0.546
# Loss after 277450 examples: 0.313
# Loss after 277500 examples: 0.790
# Loss after 277550 examples: 0.026
# Loss after 277600 examples: 0.192
# Loss after 277650 examples: 1.237
# Loss after 277700 examples: 0.472
# Loss after 277750 examples: 0.048
# Loss after 277800 examples: 0.236
# Loss after 277850 examples: 0.123
# Loss after 277900 examples: 0.244
# Loss after 277950 examples: 0.031
# Loss after 278000 examples: 1.732
# Loss after 278050 examples: 1.905
# Loss after 278100 examples: 0.545
# Loss after 278150 examples: 0.022
# Loss after 278200 examples: 0.037
# Loss after 278250 examples: 0.013
# Loss after 278300 examples: 0.169
# Loss after 278350 examples: 2.642
# Loss after 278400 examples: 0.528
# Loss after 278450 examples: 0.063
# Loss after 278500 examples: 0.174
# Loss after 278550 examples: 0.210
# Loss after 278600 examples: 0.251
# Loss after 278650 examples: 0.033
# Loss after 278700 examples: 0.603
# Loss after 278750 examples: 0.629
# Loss after 278800 examples: 0.340
# Loss after 278850 examples: 0.270
# Loss after 278900 examples: 0.138
# Loss after 278950 examples: 1.090
# Loss after 279000 examples: 0.013
# Loss after 279050 examples: 0.056
# Loss after 279100 examples: 0.060
# Loss after 279150 examples: 0.047
# Loss after 279200 examples: 1.873
# Loss after 279250 examples: 0.139
# Loss after 279300 examples: 0.375
# Loss after 279350 examples: 0.006
# Loss after 279400 examples: 0.934
# Loss after 279450 examples: 0.225
# Loss after 279500 examples: 0.713
# Loss after 279550 examples: 1.104
# Loss after 279600 examples: 2.139
# Loss after 279650 examples: 0.667
# Loss after 279700 examples: 0.290
# Loss after 279750 examples: 4.194
# Loss after 279800 examples: 0.771
# Loss after 279850 examples: 0.035
# Loss after 279900 examples: 0.837
# Loss after 279950 examples: 0.002
# Loss after 280000 examples: 2.162
# Loss after 280050 examples: 0.096
# Loss after 280100 examples: 0.040
# Loss after 280150 examples: 0.189
# Loss after 280200 examples: 0.058
# Loss after 280250 examples: 0.025
# Loss after 280300 examples: 0.023
# Loss after 280350 examples: 0.223
# Loss after 280400 examples: 0.049
# Loss after 280450 examples: 0.343
# Loss after 280500 examples: 0.663
# Loss after 280550 examples: 0.980
# Loss after 280600 examples: 0.088
# Loss after 280650 examples: 0.199
# Loss after 280700 examples: 0.461
# Loss after 280750 examples: 1.266
# Loss after 280800 examples: 0.590
# Loss after 280850 examples: 0.128
# Loss after 280900 examples: 0.129
# Loss after 280950 examples: 0.059
# Loss after 281000 examples: 0.187
# Loss after 281050 examples: 4.477
# Loss after 281100 examples: 1.546
# Loss after 281150 examples: 0.062
# Loss after 281200 examples: 0.011
# Loss after 281250 examples: 0.170
# Loss after 281300 examples: 0.006
# Loss after 281350 examples: 0.076
# Loss after 281400 examples: 0.869
# Loss after 281450 examples: 0.241
# Loss after 281500 examples: 0.295
# Loss after 281550 examples: 0.079
# Loss after 281600 examples: 1.306
# Loss after 281650 examples: 0.260
# Loss after 281700 examples: 0.429
# Loss after 281750 examples: 0.054
# Loss after 281800 examples: 0.226
# Loss after 281850 examples: 0.272
# Loss after 281900 examples: 0.712
# Loss after 281950 examples: 1.690
# Loss after 282000 examples: 1.091
# Loss after 282050 examples: 0.084
# Loss after 282100 examples: 0.069
# Loss after 282150 examples: 0.013
# Loss after 282200 examples: 0.291
# Loss after 282250 examples: 1.343
# Loss after 282300 examples: 0.813
# Loss after 282350 examples: 0.438
# Loss after 282400 examples: 0.286
# Loss after 282450 examples: 0.133
# Loss after 282500 examples: 0.378
# Loss after 282550 examples: 0.005
# Loss after 282600 examples: 0.033
# Loss after 282650 examples: 0.030
# Loss after 282700 examples: 1.297
# Loss after 282750 examples: 1.177
# Loss after 282800 examples: 1.497
# Loss after 282850 examples: 0.394
# Loss after 282900 examples: 0.122
# Loss after 282950 examples: 0.142
# Loss after 283000 examples: 0.345
# Loss after 283050 examples: 0.671
# Loss after 283100 examples: 1.432
# Loss after 283150 examples: 0.004
# Loss after 283200 examples: 0.011
# Loss after 283250 examples: 1.423
# Loss after 283300 examples: 0.011
# Loss after 283350 examples: 0.508
# Loss after 283400 examples: 0.857
# Loss after 283450 examples: 0.226
# Loss after 283500 examples: 0.003
# Loss after 283550 examples: 0.070
# Loss after 283600 examples: 0.153
# Loss after 283650 examples: 0.473
# Loss after 283700 examples: 1.301
# Loss after 283750 examples: 0.005
# Loss after 283800 examples: 0.037
# Loss after 283850 examples: 0.046
# Loss after 283900 examples: 1.596
# Loss after 283950 examples: 0.011
# Loss after 284000 examples: 0.211
# Loss after 284050 examples: 0.010
# Loss after 284100 examples: 0.582
# Loss after 284150 examples: 2.710
# Loss after 284200 examples: 0.100
# Loss after 284250 examples: 0.754
# Loss after 284300 examples: 0.739
# Loss after 284350 examples: 0.104
# Loss after 284400 examples: 1.211
# Loss after 284450 examples: 0.501
# Loss after 284500 examples: 0.064
# Loss after 284550 examples: 0.472
# Loss after 284600 examples: 0.097
# Loss after 284650 examples: 0.195
# Loss after 284700 examples: 1.147
# Loss after 284750 examples: 1.294
# Loss after 284800 examples: 0.415
# Loss after 284850 examples: 0.297
# Loss after 284900 examples: 0.071
# Loss after 284950 examples: 0.010
# Loss after 285000 examples: 0.176
# Loss after 285050 examples: 0.121
# Loss after 285100 examples: 0.238
# Loss after 285150 examples: 0.387
# Loss after 285200 examples: 0.012
# Loss after 285250 examples: 1.827
# Loss after 285300 examples: 0.417
# Loss after 285350 examples: 0.218
# Loss after 285400 examples: 0.577
# Loss after 285450 examples: 0.297
# Loss after 285500 examples: 1.113
# Loss after 285550 examples: 0.619
# Loss after 285600 examples: 0.005
# Loss after 285650 examples: 0.011
# Loss after 285700 examples: 1.591
# Loss after 285750 examples: 1.471
# Loss after 285800 examples: 0.161
# Loss after 285850 examples: 0.061
# Loss after 285900 examples: 0.002
# Loss after 285950 examples: 0.346
# Loss after 286000 examples: 0.028
# Loss after 286050 examples: 0.162
# Loss after 286100 examples: 2.682
# Loss after 286150 examples: 0.329
# Loss after 286200 examples: 3.482
# Loss after 286250 examples: 0.183
# Loss after 286300 examples: 0.032
# Loss after 286350 examples: 0.149
# Loss after 286400 examples: 0.018
# Loss after 286450 examples: 0.112
# Loss after 286500 examples: 0.010
# Loss after 286550 examples: 0.385
# Loss after 286600 examples: 0.329
# Loss after 286650 examples: 3.277
# Loss after 286700 examples: 0.046
# Loss after 286750 examples: 2.303
# Loss after 286800 examples: 0.014
# Loss after 286850 examples: 0.037
# Loss after 286900 examples: 1.248
# Loss after 286950 examples: 0.063
# Loss after 287000 examples: 0.190
# Loss after 287050 examples: 0.206
# Loss after 287100 examples: 0.093
# Loss after 287150 examples: 0.833
# Loss after 287200 examples: 0.102
# Loss after 287250 examples: 0.602
# Loss after 287300 examples: 0.916
# Loss after 287350 examples: 0.987
# Loss after 287400 examples: 0.117
# Loss after 287450 examples: 0.010
# Loss after 287500 examples: 0.158
# Loss after 287550 examples: 0.211
# Loss after 287600 examples: 0.026
# Loss after 287650 examples: 0.234
# Loss after 287700 examples: 0.137
# Loss after 287750 examples: 2.308
# Loss after 287800 examples: 0.030
# Loss after 287850 examples: 0.160
# Loss after 287900 examples: 0.042
# Loss after 287950 examples: 0.148
# Loss after 288000 examples: 2.453
# Loss after 288050 examples: 0.026
# Loss after 288100 examples: 0.201
# Loss after 288150 examples: 0.050
# Loss after 288200 examples: 0.554
# Loss after 288250 examples: 0.854
# Loss after 288300 examples: 0.081
# Loss after 288350 examples: 0.260
# Loss after 288400 examples: 0.341
# Loss after 288450 examples: 1.624
# Loss after 288500 examples: 0.849
# Loss after 288550 examples: 0.103
# Loss after 288600 examples: 0.022
# Loss after 288650 examples: 2.023
# Loss after 288700 examples: 0.008
# Loss after 288750 examples: 3.448
# Loss after 288800 examples: 0.039
# Loss after 288850 examples: 0.345
# Loss after 288900 examples: 0.051
# Loss after 288950 examples: 0.004
# Loss after 289000 examples: 0.068
# Loss after 289050 examples: 0.072
# Loss after 289100 examples: 0.153
# Loss after 289150 examples: 0.052
# Loss after 289200 examples: 0.355
# Loss after 289250 examples: 0.334
# Loss after 289300 examples: 0.033
# Loss after 289350 examples: 0.023
# Loss after 289400 examples: 1.384
# Loss after 289450 examples: 0.368
# Loss after 289500 examples: 0.097
# Loss after 289550 examples: 0.079
# Loss after 289600 examples: 0.116
# Loss after 289650 examples: 0.028
# Loss after 289700 examples: 0.040
# Loss after 289750 examples: 1.858
# Loss after 289800 examples: 0.035
# Loss after 289850 examples: 0.119
# Loss after 289900 examples: 0.093
# Loss after 289950 examples: 0.619
# Loss after 290000 examples: 0.014
# Loss after 290050 examples: 0.098
# Loss after 290100 examples: 0.015
# Loss after 290150 examples: 0.006
# Loss after 290200 examples: 0.043
# Loss after 290250 examples: 0.215
# Loss after 290300 examples: 2.105
# Loss after 290350 examples: 0.584
# Loss after 290400 examples: 0.119
# Loss after 290450 examples: 0.002
# Loss after 290500 examples: 0.000
# Loss after 290550 examples: 1.428
# Loss after 290600 examples: 0.630
# Loss after 290650 examples: 0.032
# Loss after 290700 examples: 0.025
# Loss after 290750 examples: 0.246
# Loss after 290800 examples: 0.143
# Loss after 290850 examples: 2.067
# Loss after 290900 examples: 0.013
# Loss after 290950 examples: 0.270
# Loss after 291000 examples: 1.952
# Loss after 291050 examples: 0.002
# Loss after 291100 examples: 0.061
# Loss after 291150 examples: 0.437
# Loss after 291200 examples: 0.005
# Loss after 291250 examples: 0.057
# Loss after 291300 examples: 0.800
# Loss after 291350 examples: 0.626
# Loss after 291400 examples: 0.095
# Loss after 291450 examples: 0.478
# Loss after 291500 examples: 0.730
# Loss after 291550 examples: 1.274
# Loss after 291600 examples: 2.181
# Loss after 291650 examples: 1.940
# Loss after 291700 examples: 0.015
# Loss after 291750 examples: 1.807
# Loss after 291800 examples: 0.039
# Loss after 291850 examples: 0.038
# Loss after 291900 examples: 0.009
# Loss after 291950 examples: 0.926
# Loss after 292000 examples: 0.105
# Loss after 292050 examples: 0.536
# Loss after 292100 examples: 2.153
# Loss after 292150 examples: 0.022
# Loss after 292200 examples: 0.468
# Loss after 292250 examples: 1.864
# Loss after 292300 examples: 4.332
# Loss after 292350 examples: 0.992
# Loss after 292400 examples: 0.555
# Loss after 292450 examples: 2.095
# Loss after 292500 examples: 0.028
# Loss after 292550 examples: 0.617
# Loss after 292600 examples: 0.725
# Loss after 292650 examples: 0.013
# Loss after 292700 examples: 0.216
# Loss after 292750 examples: 0.570
# Loss after 292800 examples: 0.002
# Loss after 292850 examples: 0.115
# Loss after 292900 examples: 0.338
# Loss after 292950 examples: 1.834
# Loss after 293000 examples: 0.046
# Loss after 293050 examples: 0.052
# Loss after 293100 examples: 0.027
# Loss after 293150 examples: 0.018
# Loss after 293200 examples: 0.203
# Loss after 293250 examples: 0.048
# Loss after 293300 examples: 0.150
# Loss after 293350 examples: 1.368
# Loss after 293400 examples: 0.124
# Loss after 293450 examples: 0.038
# Loss after 293500 examples: 0.016
# Loss after 293550 examples: 0.006
# Loss after 293600 examples: 0.025
# Loss after 293650 examples: 0.005
# Loss after 293700 examples: 1.601
# Loss after 293750 examples: 0.025
# Loss after 293800 examples: 1.326
# Loss after 293850 examples: 0.216
# Loss after 293900 examples: 0.122
# Loss after 293950 examples: 0.067
# Loss after 294000 examples: 0.069
# Loss after 294050 examples: 0.080
# Loss after 294100 examples: 0.185
# Loss after 294150 examples: 0.263
# Loss after 294200 examples: 0.044
# Loss after 294250 examples: 0.067
# Loss after 294300 examples: 0.139
# Loss after 294350 examples: 0.021
# Loss after 294400 examples: 0.170
# Loss after 294450 examples: 0.013
# Loss after 294500 examples: 0.167
# Loss after 294550 examples: 0.313
# Loss after 294600 examples: 0.028
# Loss after 294650 examples: 0.805
# Loss after 294700 examples: 1.106
# Loss after 294750 examples: 0.025
# Loss after 294800 examples: 0.719
# Loss after 294850 examples: 0.025
# Loss after 294900 examples: 0.034
# Loss after 294950 examples: 2.247
# Loss after 295000 examples: 0.019
# Loss after 295050 examples: 0.164
# Loss after 295100 examples: 0.908
# Loss after 295150 examples: 0.401
# Loss after 295200 examples: 0.089
# Loss after 295250 examples: 0.134
# Loss after 295300 examples: 0.040
# Loss after 295350 examples: 0.061
# Loss after 295400 examples: 0.010
# Loss after 295450 examples: 0.106
# Loss after 295500 examples: 3.271
# Loss after 295550 examples: 0.002
# Loss after 295600 examples: 0.176
# Loss after 295650 examples: 0.031
# Loss after 295700 examples: 0.009
# Loss after 295750 examples: 0.131
# Loss after 295800 examples: 0.035
# Loss after 295850 examples: 1.774
# Loss after 295900 examples: 0.080
# Loss after 295950 examples: 0.474
# Loss after 296000 examples: 0.084
# Loss after 296050 examples: 0.066
# Loss after 296100 examples: 0.904
# Loss after 296150 examples: 0.022
# Loss after 296200 examples: 0.536
# Loss after 296250 examples: 0.375
# Loss after 296300 examples: 0.318
# Loss after 296350 examples: 0.356
# Loss after 296400 examples: 0.044
# Loss after 296450 examples: 0.001
# Loss after 296500 examples: 0.787
# Loss after 296550 examples: 0.593
# Loss after 296600 examples: 0.083
# Loss after 296650 examples: 0.016
# Loss after 296700 examples: 1.239
# Loss after 296750 examples: 0.011
# Loss after 296800 examples: 0.121
# Loss after 296850 examples: 0.069
# Loss after 296900 examples: 0.039
# Loss after 296950 examples: 0.008
# Loss after 297000 examples: 0.035
# Loss after 297050 examples: 0.055
# Loss after 297100 examples: 0.118
# Loss after 297150 examples: 0.024
# Loss after 297200 examples: 0.035
# Loss after 297250 examples: 1.841
# Loss after 297300 examples: 0.051
# Loss after 297350 examples: 0.637
# Loss after 297400 examples: 2.289
# Loss after 297450 examples: 0.079
# Loss after 297500 examples: 0.243
# Loss after 297550 examples: 0.052
# Loss after 297600 examples: 0.295
# Loss after 297650 examples: 0.118
# Loss after 297700 examples: 0.939
# Loss after 297750 examples: 0.010
# Loss after 297800 examples: 0.896
# Loss after 297850 examples: 0.034
# Loss after 297900 examples: 0.052
# Loss after 297950 examples: 1.187
# Loss after 298000 examples: 0.156
# Loss after 298050 examples: 0.093
# Loss after 298100 examples: 0.073
# Loss after 298150 examples: 0.028
# Loss after 298200 examples: 0.655
# Loss after 298250 examples: 1.463
# Loss after 298300 examples: 0.004
# Loss after 298350 examples: 0.632
# Loss after 298400 examples: 0.071
# Loss after 298450 examples: 1.368
# Loss after 298500 examples: 1.326
# Loss after 298550 examples: 0.009
# Loss after 298600 examples: 0.179
# Loss after 298650 examples: 0.006
# Loss after 298700 examples: 0.043
# Loss after 298750 examples: 0.036
# Loss after 298800 examples: 0.308
# Loss after 298850 examples: 1.046
# Loss after 298900 examples: 0.159
# Loss after 298950 examples: 2.683
# Loss after 299000 examples: 0.073
# Loss after 299050 examples: 0.222
# Loss after 299100 examples: 0.087
# Loss after 299150 examples: 0.005
# Loss after 299200 examples: 1.649
# Loss after 299250 examples: 0.157
# Loss after 299300 examples: 0.744
# Loss after 299350 examples: 1.352
# Loss after 299400 examples: 0.358
# Loss after 299450 examples: 0.061
# Loss after 299500 examples: 0.799
# Loss after 299550 examples: 0.678
# Loss after 299600 examples: 0.056
# Loss after 299650 examples: 3.084
# Loss after 299700 examples: 0.482
# Loss after 299750 examples: 0.005
# Loss after 299800 examples: 0.405
# Loss after 299850 examples: 0.545
# Loss after 299900 examples: 0.225
# Loss after 299950 examples: 0.259
# Loss after 300000 examples: 0.631

# %%
model.check_accuracy(train_loader, test_loader)
# Out:
# Checking accuracy on train data
# Got 51136/60000 with accuracy 85.22666666666666
# /usr/local/lib/python3.7/dist-packages/timm/models/layers/patch_embed.py:33: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   assert H == self.img_size[0] and W == self.img_size[1], \
# /usr/local/lib/python3.7/dist-packages/torch/_tensor.py:575: UserWarning: floor_divide is deprecated, and will be removed in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values.
# To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor'). (Triggered internally at  /pytorch/aten/src/ATen/native/BinaryOps.cpp:467.)
#   return torch.floor_divide(self, other)
# Checking accuracy on test data
# Got 8585/10000 with accuracy 85.85000000000001
